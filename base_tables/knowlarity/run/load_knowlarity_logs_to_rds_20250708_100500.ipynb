# %%
# %run /home/hadoop/agrim_cdp/common_utils/db.ipynb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: psycopg2-binary in ./.local/lib/python3.9/site-packages (2.9.10)

# %%
import os
import requests
import psycopg2
from datetime import datetime, timedelta, timezone
from psycopg2.extras import execute_values
import logging

# %%
# Load credentials and configs from environment
KNOWLARITY_API_KEY = 'j5Fct1R9Dp9KriJ1r9qEsPayB8nbxwN1K4IEE3h6'       # x-api-key
KNOWLARITY_AUTH_TOKEN = 'effcd553-6e9b-4171-a1a1-444f63897939' # authorization

# %%
RDS_HOST, RDS_DBNM, RDS_USER, RDS_PASSWORD, RDS_PORT = get_rds_credentials()

# %%
logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)

# %%
def get_time_window():
    last_run = get_last_run_datetime('knowlarity')
    now = datetime.now(timezone.utc).astimezone()
    end_time = now.strftime("%Y-%m-%d %H:%M:%S%z")
    last_run = (last_run - timedelta(minutes=1))
    return last_run.strftime("%Y-%m-%d %H:%M:%S%z"), end_time

# %%
def fetch_call_logs(start_time, end_time):
    url = "https://kpi.knowlarity.com/Basic/v1/account/calllog"
    data = ""
    headers = {
        'channel': "Basic",
        'x-api-key': KNOWLARITY_API_KEY,
        'authorization': KNOWLARITY_AUTH_TOKEN,
        'content-type': "application/json"
    }

    all_logs = []
    offset = 0
    limit = 300

    while True:
        logger.info(f'Fetching Data with Offset - {offset}')
        params = {
            'start_time': start_time,
            'end_time': end_time,
            'limit': limit,
            'offset': offset
        }
        response = requests.get(url, headers=headers, params = params)
        #print(response.json())
        response.raise_for_status()
        resp_json = response.json()

        # Append current page's objects
        logs = resp_json.get('objects', [])
        all_logs.extend(logs)

        meta = resp_json.get('meta', {})
        next_url = meta.get('next')

        offset = offset + limit

        if not next_url:
            logger.info(f'No More Records to Fetch. Breaking here ....')
            break  # No more pages

    return all_logs

# %%
def normalize_call_log(raw_logs):
    normalized_logs = []
    for log in raw_logs:
        normalized_logs.append((
            log.get('id'),
            str(log.get('Call_Type')),  # stored as text
            log.get('agent_number'),
            log.get('business_call_type'),
            str(log.get('call_duration')),
            log.get('call_recording'),
            log.get('caller_name'),
            log.get('credits_deducted'),
            log.get('customer_number'),
            log.get('destination'),
            log.get('extension'),
            log.get('knowlarity_number'),
            str(log.get('order_id')),
            log.get('start_time'),
            log.get('timezone_offset'),
            log.get('uuid')
        ))
    return normalized_logs

# %%
def insert_into_postgres(logs):
    conn = psycopg2.connect(
        host=RDS_HOST,
        dbname=RDS_DBNM,
        user=RDS_USER,
        password=RDS_PASSWORD,
        port=RDS_PORT
    )
    cur = conn.cursor()

    insert_sql = """
        INSERT INTO cdp_raw_db.knowlarity_call_logs_raw (
            id, call_type, agent_number, business_call_type, call_duration, call_recording,
            caller_name, credits_deducted, customer_number, destination, extension_key,
            knowlarity_number, order_id, start_time, timezone_offset, uuid_key
        )
        VALUES %s
        ON CONFLICT (uuid_key) DO NOTHING
    """
    logger.info('Number of records inserted - ' + str(len(logs)))
    execute_values(cur,insert_sql, logs)
    #cur.execute(insert_sql, logs)

    conn.commit()
    cur.close()
    conn.close()

# %%
try:
        start_time, end_time = get_time_window()
        raw_logs = fetch_call_logs(start_time, end_time)
        logger.info(raw_logs)
        normalized_logs = normalize_call_log(raw_logs)
        if normalized_logs:
            insert_into_postgres(normalized_logs)
            update_last_run_datetime('knowlarity',end_time)
        logger.info(f'Process Completed')
except Exception as e:
        logger.info(f'There was an Exception - {e}')
# Out:
# INFO:__main__:Fetching Data with Offset - 0
# INFO:__main__:No More Records to Fetch. Breaking here ....
# INFO:__main__:[{'customer_number': '+919422835157', 'uuid': '1707991d-77d6-4765-b663-ca581b583528', 'agent_number': 'Customer Missed#+919289589977', 'call_duration': 59, 'business_call_type': 'Phone', 'id': 1, 'order_id': 0, 'destination': '+919289589977', 'Call_Type': 1, 'call_recording': '', 'knowlarity_number': '+918035760523', 'start_time': '2025-07-08 10:10:03+05:30', 'credits_deducted': '0.00', 'extension': '', 'caller_name': '', 'timezone_offset': '+0530'}, {'customer_number': '+919732564763', 'uuid': 'a3080c59-7062-4abc-a50d-8fc410a0ea60', 'agent_number': 'Customer Missed#+919821861137', 'call_duration': 53, 'business_call_type': 'Phone', 'id': 2, 'order_id': 0, 'destination': '+919821861137', 'Call_Type': 1, 'call_recording': '', 'knowlarity_number': '+918069833790', 'start_time': '2025-07-08 10:09:54+05:30', 'credits_deducted': '0.00', 'extension': '', 'caller_name': '', 'timezone_offset': '+0530'}, {'customer_number': '+919869130647', 'uuid': '5ae5d8c8-cf6d-4c6e-bcbb-bfb7effe2a11', 'agent_number': 'Customer Missed#+919818362342', 'call_duration': 55, 'business_call_type': 'Phone', 'id': 3, 'order_id': 0, 'destination': '+919818362342', 'Call_Type': 1, 'call_recording': '', 'knowlarity_number': '+918069833961', 'start_time': '2025-07-08 10:09:54+05:30', 'credits_deducted': '0.00', 'extension': '', 'caller_name': '', 'timezone_offset': '+0530'}, {'customer_number': '+919886100801', 'uuid': '8692bfb8-b8de-4034-adbd-083e74bea969', 'agent_number': '+919289102016', 'call_duration': 1348, 'business_call_type': 'Phone', 'id': 4, 'order_id': 0, 'destination': '+919289102016', 'Call_Type': 1, 'call_recording': 'https://kservices.knowlarity.com/kstorage/read?uuid=8692bfb8-b8de-4034-adbd-083e74bea969_0_1_r.mp3&server_name=BANGALORE&base_dir=recording&user_id=1390233', 'knowlarity_number': '+918035471493', 'start_time': '2025-07-08 10:09:48+05:30', 'credits_deducted': '0.00', 'extension': '', 'caller_name': '', 'timezone_offset': '+0530'}, {'customer_number': '+919993878342', 'uuid': 'ade646c8-1f55-437e-91f5-8772eae4abd8', 'agent_number': 'Customer Missed#+919821298603', 'call_duration': 46, 'business_call_type': 'Phone', 'id': 5, 'order_id': 0, 'destination': '+919821298603', 'Call_Type': 1, 'call_recording': '', 'knowlarity_number': '+918069913253', 'start_time': '2025-07-08 10:09:05+05:30', 'credits_deducted': '0.00', 'extension': '', 'caller_name': '', 'timezone_offset': '+0530'}, {'customer_number': '+918275239502', 'uuid': '37ada9fc-620b-48df-9e3d-768609e04d08', 'agent_number': 'Customer Missed#+918527591177', 'call_duration': 54, 'business_call_type': 'Phone', 'id': 6, 'order_id': 0, 'destination': '+918527591177', 'Call_Type': 1, 'call_recording': '', 'knowlarity_number': '+918035470031', 'start_time': '2025-07-08 10:08:52+05:30', 'credits_deducted': '0.00', 'extension': '', 'caller_name': '', 'timezone_offset': '+0530'}, {'customer_number': '+918766771697', 'uuid': '50339f46-f5b3-4589-be98-03450cd19099', 'agent_number': '+919599027032', 'call_duration': 573, 'business_call_type': 'Phone', 'id': 7, 'order_id': 0, 'destination': '+919599027032', 'Call_Type': 1, 'call_recording': 'https://kservices.knowlarity.com/kstorage/read?uuid=50339f46-f5b3-4589-be98-03450cd19099_0_1_r.mp3&server_name=BANGALORE&base_dir=recording&user_id=1390233', 'knowlarity_number': '+918069913254', 'start_time': '2025-07-08 10:08:33+05:30', 'credits_deducted': '0.00', 'extension': '', 'caller_name': '', 'timezone_offset': '+0530'}, {'customer_number': '+918766648338', 'uuid': '6efca160-e1c6-4faf-9afa-7687193c594f', 'agent_number': 'Customer Missed#+919818391664', 'call_duration': 55, 'business_call_type': 'Phone', 'id': 8, 'order_id': 0, 'destination': '+919818391664', 'Call_Type': 1, 'call_recording': '', 'knowlarity_number': '+918044130955', 'start_time': '2025-07-08 10:08:29+05:30', 'credits_deducted': '0.00', 'extension': '', 'caller_name': '', 'timezone_offset': '+0530'}, {'customer_number': '+918561894515', 'uuid': '08363405-bda5-4ec6-b729-93 ...
# INFO:__main__:Number of records inserted - 24
# INFO:__main__:Process Completed
